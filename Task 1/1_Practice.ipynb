# %% [markdown]
# # Session 01: Core Scientific Libraries
# ### NumPy · Pandas · Matplotlib
#
# This notebook covers:
# 1. **Git vs GitHub** — what's the difference?
# 2. **NumPy** — working with numbers and arrays
# 3. **Pandas** — loading and transforming data
# 4. **Matplotlib** — making charts
# 5. **Challenge Exercise** — putting it all together

# %% [markdown]
# ---
# ## 1. Git vs GitHub — What's the Difference?
#
# | | **Git** | **GitHub** |
# |---|---------|-----------|
# | **What is it?** | A **tool** installed on your computer | A **website** (github.com) |
# | **Purpose** | Track changes in your code (version control) | Store & share your code online |
# | **Works offline?** | ✅ Yes — runs locally | ❌ No — needs internet |
# | **Created by** | Linus Torvalds (2005) | Microsoft / GitHub Inc. (2008) |
# | **Example** | `git commit -m "fix bug"` | Pull Requests, Issues, Forks |
#
# ### Simple analogy:
# - **Git** = a diary where you write every change you make
# - **GitHub** = a cloud library where you store and share that diary with others

# %% [markdown]
# ### Git Workflow (local)
# ```
# git init                          # Start tracking a project
# git add .                         # Stage all changes
# git commit -m "my first commit"   # Save a snapshot
# git log --oneline                 # View history
# ```
#
# ### GitHub Workflow (remote)
# ```
# git remote add origin <url>       # Connect to GitHub repo
# git push origin main              # Upload your code
# git pull origin main              # Download latest changes
# git clone <url>                   # Copy a repo from GitHub
# ```
#
# > **Key point:** You use **Git** commands on your computer, and **GitHub** is where the code lives online so your team can collaborate.

# %% [markdown]
# ---
# ## 2. Setup — Verify Environment

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Importing standard libraries (NumPy, Pandas, Matplotlib) and verifying their versions to ensure our environment is ready.</p>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("All good!")
# Out:
# NumPy: 2.4.6
# Pandas: 3.0.3
# All good!

# %% [markdown]
# ---
# ## 3. NumPy — Numerical Computing
#
# **NumPy** lets you work with arrays of numbers very fast (much faster than Python lists).
#
# **When to use it:** math operations, matrices, statistics.

# %% [markdown]
# ### Create Arrays

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Creating 1D and 2D arrays (matrices) using NumPy to understand basic array structures and shapes.</p>
# </div>

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])         # 1D array
print("Array:", a)

matrix = np.array([[1, 2, 3],
                   [4, 5, 6]])          # 2D array
print("Matrix:\n", matrix)
print("Shape:", matrix.shape)

# Quick ways to create arrays
print("Zeros:", np.zeros(4))
print("Range:", np.arange(0, 10, 2))
# Out:
# Array: [1 2 3 4 5]
# Matrix:
#  [[1 2 3]
#  [4 5 6]]
# Shape: (2, 3)
# Zeros: [0. 0. 0. 0.]
# Range: [0 2 4 6 8]

# %% [markdown]
# ### Math Operations (no loops needed!)

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Performing basic mathematical operations and calculating core statistics (mean, max, sum) on NumPy arrays.</p>
# </div>

# %%
a = np.array([10, 20, 30, 40])
b = np.array([1, 2, 3, 4])

print("a + b =", a + b)
print("a * 2 =", a * 2)
print("Mean  =", np.mean(a))
print("Max   =", np.max(a))
print("Sum   =", np.sum(a))
# Out:
# a + b = [11 22 33 44]
# a * 2 = [20 40 60 80]
# Mean  = 25.0
# Max   = 40
# Sum   = 100

# %% [markdown]
# ### Indexing & Filtering

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Accessing specific elements, slicing arrays, and filtering values using boolean conditions.</p>
# </div>

# %%
arr = np.array([15, 42, 8, 73, 29, 55])

print("First:", arr[0])
print("Last:", arr[-1])
print("Slice [1:4]:", arr[1:4])

# Boolean filtering
print("Values > 30:", arr[arr > 30])
# Out:
# First: 15
# Last: 55
# Slice [1:4]: [42  8 73]
# Values > 30: [42 73 55]

# %% [markdown]
# ### Exercise: NumPy
# 1. Create an array of 6 random integers (1-100)
# 2. Print the mean and max
# 3. Replace values below 50 with 0

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Generating a random array, calculating its statistics, and replacing values that meet a specific condition.</p>
# </div>

# %%
# Solution
np.random.seed(42)
data = np.random.randint(1, 101, size=6)
print("Array:", data)
print("Mean:", np.mean(data))
print("Max:", np.max(data))

data[data < 50] = 0
print("After replacing < 50:", data)
# Out:
# Array: [52 93 15 72 61 21]
# Mean: 52.333333333333336
# Max: 93
# After replacing < 50: [52 93  0 72 61  0]

# %% [markdown]
# ---
# ## 4. Pandas — Data Manipulation
#
# **Pandas** is like Excel inside Python. It uses **DataFrames** (tables with rows and columns).
#
# **When to use it:** loading CSV files, filtering data, grouping, cleaning.

# %% [markdown]
# ### Load a CSV File

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Loading our student performance dataset from a CSV file into a Pandas DataFrame and previewing the first few rows.</p>
# </div>

# %%
import pandas as pd

df = pd.read_csv("C:/Users/Lenovo/StrategizeIT Intern/summer-intern-2026/data/students_performance.csv")
print(f"Loaded {len(df)} rows and {len(df.columns)} columns")
df.head()
# Out:
# Loaded 30 rows and 11 columns
#    student_id              name  gender  age        department  gpa  \
# 0           1  Ahmed Al-Mansour    Male   20  Computer Science  3.8
# 1           2     Fatima Hassan  Female   21  Computer Science  3.9
# 2           3       Omar Khalil    Male   22       Engineering  3.2
# 3           4      Sara Ibrahim  Female   20          Business  3.5
# 4           5    Youssef Nasser    Male   23       Engineering  2.8
#
#    study_hours_per_week  attendance_pct extracurricular scholarship  \
# 0                    25              92             Yes         Yes
# 1                    30              95             Yes         Yes
# 2                    18              78              No          No
# 3                    22              88             Yes          No
# 4                    12              65              No          No
#
#    exam_score
# 0          88
# 1          92
# 2          75
# 3          82
# 4          60

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Generating a quick statistical summary of our dataset's numerical columns.</p>
# </div>

# %%
# Quick stats
df.describe()
# Out:
#        student_id        age        gpa  study_hours_per_week  attendance_pct  \
# count   30.000000  30.000000  30.000000             30.000000       30.000000
# mean    15.500000  21.633333   3.366667             21.433333       82.800000
# std      8.803408   1.299425   0.405423              6.168235       10.688053
# min      1.000000  20.000000   2.500000             10.000000       58.000000
# 25%      8.250000  21.000000   3.100000             16.250000       76.500000
# 50%     15.500000  21.500000   3.450000             22.000000       85.500000
# 75%     22.750000  22.750000   3.700000             26.750000       91.000000
# max     30.000000  24.000000   3.900000             31.000000       96.000000
#
#        exam_score
# count   30.000000
# mean    78.433333
# std     10.972327
# min     55.000000
# 25%     70.500000
# 50%     80.500000
# 75%     86.750000
# max     94.000000

# %% [markdown]
# <li>Q1 (25%) → 25% of data is below this value.</li>
# <li>Q2 (50%) → Median (middle value).</li>
# <li>Q3 (75%) → 75% of data is below this value.</li>
#
# For your exam scores:
# <ol>
# <li>Q1 = 70.5 → about 25% of students scored 70.5 or less.</li>
# <li>Median = 80.5 → half the students scored below 80.5.</li>
# <li>Q3 = 86.75 → about 75% of students scored below 86.75.</li>
# </ol>

# %% [markdown]
# ### Filter Data

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Filtering the dataset to find our top-performing students (GPA > 3.5).</p>
# </div>

# %%
# Students with GPA above 3.5
smart = df[df["gpa"] > 3.5]
print(f"Students with GPA > 3.5: {len(smart)}")
print(smart[["name", "department", "gpa"]])
# Out:
# Students with GPA > 3.5: 12
#                 name        department  gpa
# 0   Ahmed Al-Mansour  Computer Science  3.8
# 1      Fatima Hassan  Computer Science  3.9
# 5        Noor Al-Din  Computer Science  3.7
# 7      Layla Mahmoud      Data Science  3.6
# 9       Maryam Saleh      Data Science  3.8
# 13      Huda Barakat       Engineering  3.6
# 15       Dina Othman          Business  3.7
# 17       Rana Khoury       Engineering  3.8
# 19      Lina Darwish  Computer Science  3.9
# 23         Reem Saad  Computer Science  3.6
# 27      Jana Sabbagh  Computer Science  3.7
# 29       Yasmin Awad       Engineering  3.9

# %% [markdown]
# ### Group & Summarize

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Grouping the students by department to calculate the average GPA for each department.</p>
# </div>

# %%
# Average GPA per department
print(df.groupby("department")["gpa"].mean().round(2))
# Out:
# department
# Business            3.19
# Computer Science    3.61
# Data Science        3.30
# Engineering         3.34
# Name: gpa, dtype: float64

# %% [markdown]
# ### Add New Columns

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Creating a new column to assign categorical letter grades based on the students' numerical exam scores.</p>
# </div>

# %%
# Create a letter grade column
df["grade"] = pd.cut(df["exam_score"],
                     bins=[0, 60, 70, 80, 90, 100],
                     labels=["F", "D", "C", "B", "A"])

print(df[["name", "exam_score", "grade"]].head(10))
# Out:
#                name  exam_score grade
# 0  Ahmed Al-Mansour          88     B
# 1     Fatima Hassan          92     A
# 2       Omar Khalil          75     C
# 3      Sara Ibrahim          82     B
# 4    Youssef Nasser          60     F
# 5       Noor Al-Din          86     B
# 6     Khalid Rashid          68     D
# 7     Layla Mahmoud          84     B
# 8        Hassan Ali          55     F
# 9      Maryam Saleh          90     B

# %% [markdown]
# ### Handle Missing Data

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Simulating missing data and demonstrating how to handle it by filling in the blanks with the average values.</p>
# </div>

# %%
# Simulate missing values
df_test = df[["name", "gpa"]].copy()
df_test.loc[0, "gpa"] = None
df_test.loc[3, "gpa"] = None

print("Missing values:", df_test["gpa"].isnull().sum())
print(df_test.head())
#Fill with the average
df_test["gpa"] = df_test["gpa"].fillna(df_test["gpa"].mean())
print("After filling:", df_test["gpa"].isnull().sum())
# Out:
# Missing values: 2
#                name  gpa
# 0  Ahmed Al-Mansour  NaN
# 1     Fatima Hassan  3.9
# 2       Omar Khalil  3.2
# 3      Sara Ibrahim  NaN
# 4    Youssef Nasser  2.8
# After filling: 0

# %% [markdown]
# ### Exercise: Pandas
# 1. Filter students who have a scholarship
# 2. Find average exam score per department
# 3. Sort students by exam_score (highest first)

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Solving a multi-part challenge: finding scholarship holders, calculating average scores by department, and finding top students.</p>
# </div>

# %%
# Solution
# 1. Scholarship holders
print("=== Scholarship Holders ===")
print(df[df["scholarship"] == "Yes"][["name", "department"]].to_string(index=False))

# 2. Avg exam score by department
print("\n=== Avg Exam Score ===")
print(df.groupby("department")["exam_score"].mean().round(1))

# 3. Top students
print("\n=== Top 5 by Exam Score ===")
print(df.sort_values("exam_score", ascending=False)[["name", "exam_score"]].head())
# Out:
# === Scholarship Holders ===
#             name       department
# Ahmed Al-Mansour Computer Science
#    Fatima Hassan Computer Science
#      Noor Al-Din Computer Science
#    Layla Mahmoud     Data Science
#     Maryam Saleh     Data Science
#     Huda Barakat      Engineering
#      Dina Othman         Business
#      Rana Khoury      Engineering
#     Lina Darwish Computer Science
#        Reem Saad Computer Science
#     Jana Sabbagh Computer Science
#      Yasmin Awad      Engineering
#
# === Avg Exam Score ===
# department
# Business            72.9
# Computer Science    84.8
# Data Science        77.7
# Engineering         77.6
# Name: exam_score, dtype: float64
#
# === Top 5 by Exam Score ===
#              name  exam_score
# 19   Lina Darwish          94
# 29    Yasmin Awad          93
# 1   Fatima Hassan          92
# 17    Rana Khoury          91
# 9    Maryam Saleh          90

# %% [markdown]
# ---
# ## 5. Matplotlib — Data Visualization
#
# **Matplotlib** creates charts and graphs from your data.
#
# **When to use it:** showing trends, comparing groups, presenting results.

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Creating a horizontal bar chart to visualize and compare the average GPA across different departments.</p>
# </div>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

dept_gpa = df.groupby("department")["gpa"].mean().sort_values()

plt.figure(figsize=(8, 4))
plt.barh(dept_gpa.index, dept_gpa.values, color="#6366f1")
plt.xlabel("Average GPA")
plt.title("Average GPA by Department", fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Creating a scatter plot to explore the correlation between weekly study hours and final exam scores.</p>
# </div>

# %%
plt.figure(figsize=(7, 4))
plt.scatter(df["study_hours_per_week"], df["exam_score"], c="#06b6d4", edgecolor="black", s=50)
plt.xlabel("Study Hours / Week")
plt.ylabel("Exam Score")
plt.title("Study Hours vs Exam Score", fontweight="bold")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Histogram

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Creating a histogram to visualize the distribution of exam scores across all students.</p>
# </div>

# %%
plt.figure(figsize=(7, 4))
plt.hist(df["exam_score"], bins=8, color="#10b981", edgecolor="white")
plt.axvline(df["exam_score"].mean(), color="red", linestyle="--", label=f'Mean: {df["exam_score"].mean():.0f}')
plt.xlabel("Exam Score")
plt.ylabel("Count")
plt.title("Exam Score Distribution", fontweight="bold")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pie Chart

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Creating a pie chart to visualize the proportion of students enrolled in each department.</p>
# </div>

# %%
counts = df["department"].value_counts()

plt.figure(figsize=(5, 5))
plt.pie(counts, labels=counts.index, autopct="%1.2f%%",
        colors=["#6366f1","#06b6d4","#10b981","#f59e0b"])
plt.title("Students by Department", fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 6. Challenge Exercise
#
# > **Goal:** Load data → 3 transformations → 1 visualization

# %% [markdown]
# ### Step 1: Load

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Loading our student performance dataset from a CSV file into a Pandas DataFrame and previewing the first few rows.</p>
# </div>

# %%
df = pd.read_csv("data/students_performance.csv")
print(f"Loaded {len(df)} students")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df = pd.read_csv("data/students_performance.csv")
#       2 print(f"Loaded {len(df)} students")
#
# File c:\Users\Lenovo\AppData\Local\pypoetry\Cache\virtualenvs\package-1FzKafzK-py3.13\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ### Step 2: Transform

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Filtering for active students (high attendance) and calculating their average exam scores grouped by department.</p>
# </div>

# %%
# Transformation 1 — Filter: only students with attendance >= 80%
df_active = df[df["attendance_pct"] >= 80]
print(f"Active students (attendance >= 80%): {len(df_active)}")

# Transformation 2 — Group: average score by department
#computes the average exam score within each department group (using only active students, since we're working off df_active).
dept_scores = df_active.groupby("department")["exam_score"].mean().round(1)
print("\nAvg exam score by department:")
print(dept_scores)

# Transformation 3 — New column: pass/fail
df_active = df_active.copy()
df_active["status"] = df_active["exam_score"].apply(lambda x: "Pass" if x >= 70 else "Fail")
print("\nPass/Fail counts:")
print(df_active["status"].value_counts())

# %% [markdown]
# ### Step 3: Visualize

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Creating a dashboard with multiple charts side-by-side to visualize both average scores and pass/fail rates at a glance.</p>
# </div>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Chart 1: Avg score by department
dept_scores.sort_values().plot(kind="barh", ax=ax1, color="#6366f1")
ax1.set_title("Avg Exam Score by Dept", fontweight="bold")
ax1.set_xlabel("Score")

# Chart 2: Pass vs Fail
status = df_active["status"].value_counts()
ax2.pie(status, labels=status.index, autopct="%1.0f%%", colors=["#10b981","#ef4444"])
ax2.set_title("Pass vs Fail (Active Students)", fontweight="bold")

plt.tight_layout()
plt.show()

print("Insight: Students with >= 80% attendance have a high pass rate!")

# %% [markdown]
# ---
# ## Summary
#
# | Library | What it does | Example |
# |---------|-------------|---------|
# | **NumPy** | Fast math on arrays | `np.mean(arr)` |
# | **Pandas** | Load, filter, group data | `df.groupby("col").mean()` |
# | **Matplotlib** | Make charts | `plt.bar(x, y)` |
#
# | Tool | What it is |
# |------|-----------|
# | **Git** | Version control on your computer |
# | **GitHub** | Online platform to share code |
# | **Poetry** | Python dependency manager |
#
# > **Next step:** Try changing the exercises to use your own data!

# %% [markdown]
# ---
# ## Part 5: GeoPandas
#
# GeoPandas extends the datatypes used by pandas to allow spatial operations on geometric types. It makes working with geospatial data in Python easier.
#
# In this example, we will load a built-in dataset containing the map of the world and plot it.

# %% [markdown]
# <div style="background-color: #f0fdf4; padding: 15px; border-left: 5px solid #22c55e; border-radius: 5px; margin-bottom: 10px;">
#     <h4 style="color: #166534; margin-top: 0;">🎯 What are we doing here?</h4>
#     <p style="color: #15803d; margin-bottom: 0; font-size: 14px;">Loading and displaying a world map dataset using GeoPandas to explore geospatial data handling.</p>
# </div>

# %% [markdown]
# Run -> `poetry add geopandas geodatasets`

# %%
import geopandas as gpd
import geodatasets
import matplotlib.pyplot as plt

# Load the built-in naturalearth_lowres dataset using geodatasets (new standard for GeoPandas 1.0+)
dataset_path = geodatasets.get_path('naturalearth.land')
world = gpd.read_file(dataset_path)

# Display the first few rows
display(world.head())

# Plot the world map
world.plot(figsize=(10, 6), color='lightblue', edgecolor='black')
plt.title('World Map using GeoPandas')
plt.show()

# %%
from shapely.geometry import Point, LineString, Polygon, MultiPolygon
import matplotlib.pyplot as plt

# Create a Point
pt = Point(2, 3)

# Create a LineString
line = LineString([(0, 0), (2, 3), (4, 5)])

# Create a Polygon
poly = Polygon([(0, 0), (4, 0), (4, 4), (0, 4)])

# Create a MultiPolygon
poly1 = Polygon([(6, 0), (8, 0), (8, 2), (6, 2)])
poly2 = Polygon([(9, 0), (10, 0), (10, 1), (9, 1)])
multi_poly = MultiPolygon([poly1, poly2])

# Show differences
print("Point:", pt)
print("Type:", type(pt))
print("\nLineString:", line)
print("Type:", type(line))
print("\nPolygon:", poly)
print("Type:", type(poly))
print("\nMultiPolygon:", multi_poly)
print("Type:", type(multi_poly))

# Plot each geometry
fig, axs = plt.subplots(1, 4, figsize=(12, 4))

# Point
axs[0].scatter(*pt.xy, color='red')
axs[0].set_title("Point")
axs[0].set_xlim(-1, 5)
axs[0].set_ylim(-1, 5)

# LineString
x, y = line.xy
axs[1].plot(x, y, color='blue')
axs[1].set_title("LineString")
axs[1].set_xlim(-1, 5)
axs[1].set_ylim(-1, 6)

# Polygon
x, y = poly.exterior.xy
axs[2].fill(x, y, color='green', alpha=0.5)
axs[2].set_title("Polygon")
axs[2].set_xlim(-1, 5)
axs[2].set_ylim(-1, 5)

# MultiPolygon
for geom in multi_poly.geoms:
    x, y = geom.exterior.xy
    axs[3].fill(x, y, color='orange', alpha=0.5)
axs[3].set_title("MultiPolygon")
axs[3].set_xlim(5, 11)
axs[3].set_ylim(-1, 3)

for ax in axs:
    ax.set_aspect('equal')
    ax.axis('off')

plt.tight_layout()
plt.show()
